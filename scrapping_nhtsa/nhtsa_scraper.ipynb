# %%
from playwright.async_api import async_playwright
from bs4 import BeautifulSoup

async def scrape_with_playwright_async(make="TOYOTA", model="COROLLA", year="2020"):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=False)
        page = await browser.new_page()
        
        await page.goto("https://www.nhtsa.gov/recalls")
        await page.wait_for_timeout(3000)

        await page.select_option("#edit-make", make)
        await page.select_option("#edit-model", model)
        await page.select_option("#edit-year", year)

        await page.click("#edit-submit--2")
        await page.wait_for_load_state("networkidle")
        await page.wait_for_timeout(5000)

        html = await page.content()
        soup = BeautifulSoup(html, 'html.parser')

        results = []
        cards = soup.select(".views-row")
        for card in cards:
            title = card.select_one("h3").text.strip() if card.select_one("h3") else "N/A"
            description = card.select_one("div.field-content").text.strip() if card.select_one("div.field-content") else "N/A"
            results.append((title, description))

        await browser.close()
        return results

# %%
data = await scrape_with_playwright_async()

# View results
for entry in data:
    print(entry)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data = await scrape_with_playwright_async()
#       3 # View results
#       4 for entry in data:
#
# Cell In[5], line 5, in scrape_with_playwright_async(make, model, year)
#       4 async def scrape_with_playwright_async(make="TOYOTA", model="COROLLA", year="2020"):
# ----> 5     async with async_playwright() as p:
#       6         browser = await p.chromium.launch(headless=False)
#       7         page = await browser.new_page()
#
# File c:\Users\bxmaq\Downloads\code\LANGCHAIN\venv\lib\site-packages\playwright\async_api\_context_manager.py:46, in PlaywrightContextManager.__aenter__(self)
#      44 if not playwright_future.done():
#      45     playwright_future.cancel()
# ---> 46 playwright = AsyncPlaywright(next(iter(done)).result())
#      47 playwright.stop = self.__aexit__  # type: ignore
# ...
